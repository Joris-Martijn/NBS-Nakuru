# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path_ter = r"C:\Users\jmsch\2025-06-02_wflow_qgis"
path_cal = r"C:\Users\jmsch\OneDrive\Documenten\Studie\Civiele Techniek\Environmental Engineering\Year 2\Afstuderen\NBS Nakuru Kenia\2. QGIS + Wflow\Wflow - WitteveenBos\wflow_JMS\HydroMT"

q_terracing = pd.read_csv(f"{path_ter}/wflow_test_terracing/fx0.4_tsx8_khx.05_kvx3_L50/output.csv", index_col=0, parse_dates=True)
q_all_terracing = pd.read_csv(f"{path_ter}/wflow_test_terracing/fx0.4_tsx8_khx.05_kvx3_L50_slope0.5/output.csv", index_col=0, parse_dates=True)
q_calibration = pd.read_csv(f"{path_cal}/Nakuru_res0.002dg_complete_chirps/fx0.4_tsx8_khx.05_kvx3_L50/output.csv", index_col=0, parse_dates=True)

# %%
q_all_terracing['Q_2'].plot(figsize=(15, 5), label='Q_2 All Terracing', color='green')

q_terracing['Q_2'].plot(label='Q_2 Terracing', color='blue')
q_calibration['Q_2'].plot(label='Q_2 Calibration', color='orange')

plt.title('Q_2 Comparison')
plt.xlabel('Date')
plt.ylabel('Discharge (m³/s)')
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig(f"{path_ter}/Q_2_comparison.png", dpi=300)

# %%
q_all_terracing['Q_1'].plot(figsize=(15, 5), label='Q_1 All Terracing', color='green')

q_terracing['Q_1'].plot(label='Q_1 Terracing', color='blue')
q_calibration['Q_1'].plot(label='Q_1 Calibration', color='orange')

plt.title('Q_1 Comparison')
plt.xlabel('Date')
plt.ylabel('Discharge (m³/s)')
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig(f"{path_ter}/Q_1_comparison.png", dpi=300)
